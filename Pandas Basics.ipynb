# %%
import numpy as pandas
import pandas as pd
# We can install pandas and numpy on notebook
# !pip install pandas

# %%
labels=['a','b','c']
labels
# Out:
# ['a', 'b', 'c']

# %%
my_data=[10,20,30]
my_data
# Out:
# [10, 20, 30]

# %%
arr=np.array(my_data)
arr
# Out:
# array([10, 20, 30])

# %%
d={'x':10,'y':20,'z':30}
d
# Out:
# {'x': 10, 'y': 20, 'z': 30}

# %%
#pd.Series(data,index)
pd.Series(data=my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_data,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# x    10
# y    20
# z    30
# dtype: int64

# %%
'''If we write 3 index element and 4 data elemen tthen it will give error both the index and data sizes must be same
lst=[10,20,30,40]
ind=['l','m','n']
pd.Series(lst,ind)'''
# Out:
# "If we write 3 index element and 4 data elemen tthen it will give error both the index and data sizes must be same\nlst=[10,20,30,40]\nind=['l','m','n']   \npd.Series(lst,ind)"

# %%
#String is known as object in pandas
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
# pass built in function as data so in op it will show that they are built in functions
pd.Series(data=[sum,len,print])
# Out:
# 0      <built-in function sum>
# 1      <built-in function len>
# 2    <built-in function print>
# dtype: object

# %%
ser1=pd.Series([10,20,30,40],['USA','Japan','Italy','France'])
ser1
# Out:
# USA       10
# Japan     20
# Italy     30
# France    40
# dtype: int64

# %%
ser2=pd.Series([10,20,50,40],['USA','Japan','Korea','France'])
ser2
# Out:
# USA       10
# Japan     20
# Korea     50
# France    40
# dtype: int64

# %%
#indexing USA is index value
ser1['USA']
# Out:
# 10

# %%
ser2['Korea']
# Out:
# 50

# %%
ser1+ser2
# Out:
# France    80.0
# Italy      NaN
# Japan     40.0
# Korea      NaN
# USA       20.0
# dtype: float64
