# %%
import pandas as pd
#read csv file
df=pd.read_csv('data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    110       NaN       NaN
# 2          60    103     135.0     340.0
# 3          45    109       NaN       NaN
# 4         450    117     148.0     406.0
# ..        ...    ...       ...       ...
# 164        60    105     140.0     290.8
# 165        60    110     145.0     300.4
# 166        60    115     145.0     310.2
# 167        75    120     150.0     320.4
# 168        75    125     150.0     330.4
#
# [169 rows x 4 columns]

# %%
#First five values
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110     130.0     409.1
# 1        60    110       NaN       NaN
# 2        60    103     135.0     340.0
# 3        45    109       NaN       NaN
# 4       450    117     148.0     406.0

# %%
#Last five values
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105     140.0     290.8
# 165        60    110     145.0     300.4
# 166        60    115     145.0     310.2
# 167        75    120     150.0     320.4
# 168        75    125     150.0     330.4

# %%
#Gives all the information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  167 non-null    float64
#  3   Calories  161 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 5.4 KB

# %%
#Gives data in statistical form
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  167.000000   161.000000
# mean    66.242604  107.372781  133.682635   375.750311
# std     51.662196   14.497437   16.223250   268.637503
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.700000
# 50%     60.000000  105.000000  131.000000   318.000000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    450.000000  159.000000  184.000000  1860.400000

# %%
#Check the values are null or not
df.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False      True      True
# 2       False  False     False     False
# 3       False  False      True      True
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
#delete the rows whose values are null
newdf=df.dropna()
newdf
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 2          60    103     135.0     340.0
# 4         450    117     148.0     406.0
# 6          60    102     127.0     300.5
# 7          45    104     134.0     253.3
# ..        ...    ...       ...       ...
# 164        60    105     140.0     290.8
# 165        60    110     145.0     300.4
# 166        60    115     145.0     310.2
# 167        75    120     150.0     320.4
# 168        75    125     150.0     330.4
#
# [161 rows x 4 columns]

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  161 non-null    int64
#  1   Pulse     161 non-null    int64
#  2   Maxpulse  161 non-null    float64
#  3   Calories  161 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 6.3 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  167 non-null    float64
#  3   Calories  161 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 5.4 KB

# %%
#inplace of nan fill 100
df.fillna(100)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    110     100.0     100.0
# 2          60    103     135.0     340.0
# 3          45    109     100.0     100.0
# 4         450    117     148.0     406.0
# ..        ...    ...       ...       ...
# 164        60    105     140.0     290.8
# 165        60    110     145.0     300.4
# 166        60    115     145.0     310.2
# 167        75    120     150.0     320.4
# 168        75    125     150.0     330.4
#
# [169 rows x 4 columns]

# %%
#fill values on particular column
df['Calories'].fillna(150)
# Out:
# 0      409.1
# 1      150.0
# 2      340.0
# 3      150.0
# 4      406.0
#        ...
# 164    290.8
# 165    300.4
# 166    310.2
# 167    320.4
# 168    330.4
# Name: Calories, Length: 169, dtype: float64

# %%
#find mean of particular column
x=df['Calories'].mean()
x
# Out:
# 375.7503105590062

# %%
#Fill that mean inplace of null values bt changes not applicable on original data
df['Calories'].fillna(x)
# Out:
# 0      409.100000
# 1      375.750311
# 2      340.000000
# 3      375.750311
# 4      406.000000
#           ...
# 164    290.800000
# 165    300.400000
# 166    310.200000
# 167    320.400000
# 168    330.400000
# Name: Calories, Length: 169, dtype: float64

# %%
#Find the median of particular column
x=df['Calories'].median()
x
# Out:
# 318.0

# %%
#place that median value inplace of nan
df['Calories'].fillna(x)
# Out:
# 0      409.1
# 1      318.0
# 2      340.0
# 3      318.0
# 4      406.0
#        ...
# 164    290.8
# 165    300.4
# 166    310.2
# 167    320.4
# 168    330.4
# Name: Calories, Length: 169, dtype: float64

# %%
#Find mode of particular column. In case of mode writing [0] is mandatory
x=df['Calories'].mode()[0]
x
# Out:
# 300.0

# %%
#Fill the valu of mode inplace of nan
df['Calories'].fillna(x)
# Out:
# 0      409.1
# 1      300.0
# 2      340.0
# 3      300.0
# 4      406.0
#        ...
# 164    290.8
# 165    300.4
# 166    310.2
# 167    320.4
# 168    330.4
# Name: Calories, Length: 169, dtype: float64
